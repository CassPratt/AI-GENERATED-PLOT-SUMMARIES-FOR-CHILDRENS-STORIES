# %% [markdown]
# # Manual image captioning

# %%
# import required modules
import os
from PIL import Image

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import csv

# %%
# Images directory
directory = './Datasets review/book-dataset-uchidalab/childrens-books'

# %%
# Create list of files in directory
dir_list = os.listdir(directory)

# %%
# Function to split a list a in n subsets
def split(a, n):
    k, m = divmod(len(a), n)
    return (a[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))

# %%
# Split list of images in 171 subsets of size 10 (index 0 to 170)
split_list = list(split(dir_list,171))

# %%
# iterate over files in
# that directory
def enter_caption(list_subset):
    for filename in split_list[list_subset]:
        f = os.path.join(directory, filename)
        # checking if it is a file
        if os.path.isfile(f):
            imgplot = plt.imshow(mpimg.imread(f))
            plt.ion()
            plt.show()
            img_desc = input('Enter image description: ')
            img_dict[filename] = img_desc
            plt.close()

# %%
# Dictionary to store images captions
img_dict = {}

# Select subset to caption
# Already captioned: 0 to 52
list_subset = 53

# flag to iterate subsets
keep_captioning = True

while keep_captioning:
    enter_caption(list_subset)
    input_resp = input('Continue with next set? (y/n): ')
    if input_resp == 'y':
        list_subset += 1
    else:
        keep_captioning = False

print('Last subset index was', list_subset)
# Out:
# Enter image description: drawing of a girl singing and picture of a woman with the title "WHEN I GROW UP Taylor Swift"
# Enter image description: drawing of an elephant and two pigs with toys and the title "Dentist Trip"
# Enter image description: drawing of a sword stuck in water with the title "Parsifal's Page"
# Enter image description: drawing of a man holding a stick with the title "The Quest of the Fair Unknown"
# Enter image description: picture of elephants with the title "ELEPHANT SCIENTITS"
# Enter image description: drawing of a knight with a shield and a sword with the title "The Legend of the King"
# Enter image description: picture of a lemonade glass with the title "The Lemonade War"
# Enter image description: drawing of a monkey with a red hat and snowflakes with the title "Curious George Christmas Countdown"
# Enter image description: drawing of a man working in a table with the title "SNOWFLAKE BENTLEY"
# ...

# %%
img_dict
# Out:
# {'0545862612.jpg': 'drawing of a girl singing and picture of a woman with the title "WHEN I GROW UP Taylor Swift"',
#  '0545891469.jpg': 'drawing of an elephant and two pigs with toys and the title "Dentist Trip"',
#  '0547014341.jpg': 'drawing of a sword stuck in water with the title "Parsifal\'s Page"',
#  '0547014848.jpg': 'drawing of a man holding a stick with the title "The Quest of the Fair Unknown"',
#  '0547053444.jpg': 'picture of elephants with the title "ELEPHANT SCIENTITS"',
#  '0547144202.jpg': 'drawing of a knight with a shield and a sword with the title "The Legend of the King"',
#  '0547237650.jpg': 'picture of a lemonade glass with the title "The Lemonade War"',
#  '0547238630.jpg': 'drawing of a monkey with a red hat and snowflakes with the title "Curious George Christmas Countdown"',
#  '0547248296.jpg': 'drawing of a man working in a table with the title "SNOWFLAKE BENTLEY"',
# ...

# %%
len(img_dict.keys())
# Out:
# 10

# %%
# Open the CSV file in "append" mode
with open('childrens-books-captions.csv', 'a', newline='') as f:
    # Create a dictionary writer with the dict keys as column fieldnames
    writer = csv.writer(f)
    # Append single row to CSV
    for row in img_dict.items():
        writer.writerow(row)
